# %% [markdown]
# # Example Data Science Problem
#
# In this example, we'll generate a synthetic dataset, perform exploratory data analysis (EDA), fit a simple linear regression model, and visualize the results.

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error, r2_score
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %% [markdown]
# ### Generate Synthetic Data

# %%
np.random.seed(42)
X = np.linspace(0, 10, 50)
y = 2.5 * X + np.random.normal(0, 3, size=X.shape)
data = pd.DataFrame({'X': X, 'y': y})
data.head()
# Out:
#           X         y
# 0  0.000000  1.490142
# 1  0.204082  0.095411
# 2  0.408163  2.963474
# 3  0.612245  6.099702
# 4  0.816327  1.338356

# %% [markdown]
# ### Exploratory Data Analysis (EDA)
#
# Visualize the relationship between X and y.

# %%
plt.scatter(data['X'], data['y'], color='cornflowerblue', label='Data points')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Scatter plot of X vs y')
plt.legend()
plt.show()

# %% [markdown]
# ### Fit a Linear Regression Model
#
# Now we'll fit a simple linear regression model to predict y from X.

# %%
model = LinearRegression()
model.fit(data[['X']], data['y'])

print(f"Intercept: {model.intercept_:.2f}")
print(f"Slope: {model.coef_[0]:.2f}")
# Out:
# Intercept: 0.19
# Slope: 2.33

# %%
# Plot regression line
plt.scatter(data['X'], data['y'], color='cornflowerblue', label='Data points')
plt.plot(data['X'], model.predict(data[['X']]), color='black', label='Regression line')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression Fit')
plt.legend()
plt.show()

# %%
# Predict y values using the trained model
y_pred = model.predict(data[['X']])

# Calculate evaluation metrics
rmse = root_mean_squared_error(data['y'], y_pred)
r2 = r2_score(data['y'], y_pred)

print(f"Root Mean Squared Error: {rmse:.2f}")
print(f"R^2 Score: {r2:.2f}")
# Out:
# Root Mean Squared Error: 2.73
# R^2 Score: 0.86

# %%
# Residual plot
residuals = data['y'] - y_pred

fig, axs = plt.subplots(1,2, figsize=(12,5))

# Residual Scatterplot
ax0=axs.flatten()[0]
ax0.scatter(data['X'], residuals, color='salmon', alpha=0.7)
ax0.axhline(0, color='black', linestyle='--')
ax0.set_xlabel('X')
ax0.set_ylabel('Residuals')
ax0.set_title('Residual Plot')

# Residual Histogram
ax1=axs.flatten()[1]
ax1.hist(residuals, bins=10, color='salmon', edgecolor='black')
ax1.set_xlabel('Residual')
ax1.set_ylabel('Frequency')
ax1.set_title('Histogram of Residuals')

plt.show()

# %% [markdown]
# ## Summary
#
# - We generated synthetic data with a linear relationship and noise.
# - Performed EDA with a scatter plot.
# - Fit a linear regression model and visualized the fit.
#
# **Next steps:** Try experimenting with more features, different models, or adding more noise to the data!
